# %%
import pandas as pd

# %%
df_bookings = pd.read_csv('datasets/fact_bookings.csv')
df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
df_bookings.shape
# Out:
# (134590, 12)

# %%
df_bookings['room_category'].unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
df_bookings['booking_platform'].unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
df_bookings['booking_platform'].value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
df_bookings['booking_platform'].value_counts().plot(kind = 'bar', rot = 45)
# Out:
# <Axes: xlabel='booking_platform'>

# %%
df_bookings.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %%
df_date = pd.read_csv('datasets/dim_date.csv')
df_hotels = pd.read_csv('datasets/dim_hotels.csv')
df_rooms = pd.read_csv('datasets/dim_rooms.csv')
df_aggregated_bookings = pd.read_csv('datasets/fact_aggregated_bookings.csv')

# %%
df_hotels.shape
# Out:
# (25, 4)

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df_hotels.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts()
# Out:
# city
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: count, dtype: int64

# %%
df_hotels.city.value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='city'>

# %%
df_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
#Exercise-1. Find out unique property ids in aggregate bookings dataset

df_aggregated_bookings.property_id.unique()
# Out:
# array([16559, 19562, 19563, 17558, 16558, 17560, 19558, 19560, 17561,
#        16560, 16561, 16562, 16563, 17559, 17562, 17563, 18558, 18559,
#        18561, 18562, 18563, 19559, 19561, 17564, 18560], dtype=int64)

# %%
#Exercise-2. Find out total bookings per property_id

df_aggregated_bookings.property_id.value_counts()
# Out:
# property_id
# 16559    368
# 17559    368
# 17564    368
# 19561    368
# 19559    368
# 18563    368
# 18562    368
# 18561    368
# 18559    368
# 18558    368
# 17563    368
# 17562    368
# 16563    368
# 19562    368
# 16562    368
# 16561    368
# 16560    368
# 17561    368
# 19560    368
# 19558    368
# 17560    368
# 16558    368
# 17558    368
# 19563    368
# 18560    368
# Name: count, dtype: int64

# %%
#Exercise-3. Find out days on which bookings are greater than capacity

df_aggregated_bookings[df_aggregated_bookings['successful_bookings'] > df_aggregated_bookings['capacity']]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
#Exercise-4. Find out properties that have highest capacity

df_aggregated_bookings[df_aggregated_bookings['capacity'] == df_aggregated_bookings['capacity'].max()]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 27          17558      1-May-22           RT2                   38      50.0
# 128         17558      2-May-22           RT2                   27      50.0
# 229         17558      3-May-22           RT2                   26      50.0
# 328         17558      4-May-22           RT2                   27      50.0
# 428         17558      5-May-22           RT2                   29      50.0
# ...           ...           ...           ...                  ...       ...
# 8728        17558     27-Jul-22           RT2                   22      50.0
# 8828        17558     28-Jul-22           RT2                   21      50.0
# 8928        17558     29-Jul-22           RT2                   23      50.0
# 9028        17558     30-Jul-22           RT2                   32      50.0
# 9128        17558     31-Jul-22           RT2                   30      50.0
#
# [92 rows x 5 columns]

# %%
df_bookings = df_bookings[df_bookings['no_guests'] > 0]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.revenue_generated.min(), df_bookings.revenue_generated.max()
# Out:
# (6500, 28560000)

# %%
avg, std = df_bookings.revenue_generated.mean(), df_bookings.revenue_generated.std()
avg, std
# Out:
# (15378.036937686695, 93040.15493143328)

# %%
higher_limit = avg + 3 * std
higher_limit
# Out:
# 294498.50173198653

# %%
df_bookings[df_bookings.revenue_generated > higher_limit]
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 2        May012216558RT13        16558     28-04-22      1/5/2022
# 111      May012216559RT32        16559     29-04-22      1/5/2022
# 315      May012216562RT22        16562     28-04-22      1/5/2022
# 562     May012217559RT118        17559     26-04-22      1/5/2022
# 129176   Jul282216562RT26        16562     21-07-22      28-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 2           4/5/2022        2.0           RT1          logtrip            5.0
# 111         2/5/2022        6.0           RT3    direct online            NaN
# 315         4/5/2022        2.0           RT2   direct offline            3.0
# 562         2/5/2022        2.0           RT1           others            NaN
# 129176      29-07-22        2.0           RT2    direct online            3.0
#
#        booking_status  revenue_generated  revenue_realized
# ...

# %%
df_bookings = df_bookings[df_bookings.revenue_generated < higher_limit]
df_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 1        May012216558RT12        16558     30-04-22      1/5/2022
# 4        May012216558RT15        16558     27-04-22      1/5/2022
# 5        May012216558RT16        16558     1/5/2022      1/5/2022
# 6        May012216558RT17        16558     28-04-22      1/5/2022
# 7        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134584   Jul312217564RT45        17564     30-07-22      31-07-22
# 134585   Jul312217564RT46        17564     29-07-22      31-07-22
# 134587   Jul312217564RT48        17564     30-07-22      31-07-22
# 134588   Jul312217564RT49        17564     29-07-22      31-07-22
# 134589  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 1           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_bookings.revenue_realized.describe()
# Out:
# count    134573.000000
# mean      12695.983585
# std        6927.791692
# min        2600.000000
# 25%        7600.000000
# 50%       11700.000000
# 75%       15300.000000
# max       45220.000000
# Name: revenue_realized, dtype: float64

# %%
12695.983585 + 3 * 6927.791692
# Out:
# 33479.358661

# %%
df_bookings.isnull().sum()
# Out:
# booking_id               0
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        77897
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# dtype: int64

# %%
df_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
df_aggregated_bookings.isnull().sum()
# Out:
# property_id            0
# check_in_date          0
# room_category          0
# successful_bookings    0
# capacity               2
# dtype: int64

# %%
df_aggregated_bookings[df_aggregated_bookings['capacity'].isnull()]
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 8         17561      1-May-22           RT1                   22       NaN
# 14        17562      1-May-22           RT1                   12       NaN

# %%
#**Exercise-1. In aggregate bookings find columns that have null values. Fill these null values with whatever you think is the appropriate subtitute (possible ways is to use mean or median)

df_aggregated_bookings = df_aggregated_bookings.fillna({
    'capacity' : df_aggregated_bookings['capacity'].median()
})
df_aggregated_bookings.head(15)
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 0         16559      1-May-22           RT1                   25      30.0
# 1         19562      1-May-22           RT1                   28      30.0
# 2         19563      1-May-22           RT1                   23      30.0
# 3         17558      1-May-22           RT1                   30      19.0
# 4         16558      1-May-22           RT1                   18      19.0
# 5         17560      1-May-22           RT1                   28      40.0
# 6         19558      1-May-22           RT1                   25      40.0
# 7         19560      1-May-22           RT1                   23      26.0
# 8         17561      1-May-22           RT1                   22      25.0
# 9         16560      1-May-22           RT1                   24      34.0
# 10        16561      1-May-22           RT1                   16      18.0
# ...

# %%
df_aggregated_bookings[df_aggregated_bookings['successful_bookings'] > df_aggregated_bookings['capacity']]
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 3           17558      1-May-22           RT1                   30      19.0
# 12          16563      1-May-22           RT1                  100      41.0
# 4136        19558     11-Jun-22           RT2                   50      39.0
# 6209        19560      2-Jul-22           RT1                  123      26.0
# 8522        19559     25-Jul-22           RT1                   35      24.0
# 9194        18563     31-Jul-22           RT4                   20      18.0

# %%
df_aggregated_bookings = df_aggregated_bookings[df_aggregated_bookings['successful_bookings'] <= df_aggregated_bookings['capacity']]
df_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0

# %%
df_aggregated_bookings['occ_pct'] = df_aggregated_bookings['successful_bookings'] / df_aggregated_bookings['capacity']

# %%
df_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#     occ_pct
# 0  0.833333
# 1  0.933333
# 2  0.766667
# 4  0.947368
# 5  0.700000

# %%
def multiply(x, y):
    return round((x * y), 2)

df_aggregated_bookings['occ_pct'] = multiply(df_aggregated_bookings['occ_pct'], 100)

# %%
df_aggregated_bookings.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 4        16558      1-May-22           RT1                   18      19.0
# 5        17560      1-May-22           RT1                   28      40.0
#
#    occ_pct
# 0    83.33
# 1    93.33
# 2    76.67
# 4    94.74
# 5    70.00

# %%
df_aggregated_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9194 entries, 0 to 9199
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9194 non-null   int64
#  1   check_in_date        9194 non-null   object
#  2   room_category        9194 non-null   object
#  3   successful_bookings  9194 non-null   int64
#  4   capacity             9194 non-null   float64
#  5   occ_pct              9194 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 502.8+ KB

# %%
#1. What is an average occupancy rate in each of the room categories?

df_aggregated_bookings.groupby('room_category')['occ_pct'].mean().round(2)
# Out:
# room_category
# RT1    57.89
# RT2    58.01
# RT3    58.03
# RT4    59.28
# Name: occ_pct, dtype: float64

# %%
df_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
df = pd.merge(df_aggregated_bookings, df_rooms, left_on = 'room_category', right_on = 'room_id')
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#    occ_pct room_id room_class
# 0    83.33     RT1   Standard
# 1    93.33     RT1   Standard
# 2    76.67     RT1   Standard
# 3    94.74     RT1   Standard
# 4    70.00     RT1   Standard

# %%
df.groupby('room_class')['occ_pct'].mean().round(2)
# Out:
# room_class
# Elite           58.01
# Premium         58.03
# Presidential    59.28
# Standard        57.89
# Name: occ_pct, dtype: float64

# %%
df.groupby('room_class')['occ_pct'].mean().round(2).plot(kind = 'bar', rot = 45, title = 'Occupancy % By Room Class')
# Out:
# <Axes: title={'center': 'Occupancy % By Room Class'}, xlabel='room_class'>

# %%
df.drop('room_id', axis = 1, inplace = True)
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        16558      1-May-22           RT1                   18      19.0
# 4        17560      1-May-22           RT1                   28      40.0
#
#    occ_pct room_class
# 0    83.33   Standard
# 1    93.33   Standard
# 2    76.67   Standard
# 3    94.74   Standard
# 4    70.00   Standard

# %%
#2. Print avg. occupancy rate per city

df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
df = pd.merge(df, df_hotels, on = 'property_id')
df.head()
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity  \
# 0        16559      1-May-22           RT1                   25      30.0
# 1        16559      2-May-22           RT1                   20      30.0
# 2        16559      3-May-22           RT1                   17      30.0
# 3        16559      4-May-22           RT1                   21      30.0
# 4        16559      5-May-22           RT1                   16      30.0
#
#    occ_pct room_class  property_name category    city
# 0    83.33   Standard  Atliq Exotica   Luxury  Mumbai
# 1    66.67   Standard  Atliq Exotica   Luxury  Mumbai
# 2    56.67   Standard  Atliq Exotica   Luxury  Mumbai
# 3    70.00   Standard  Atliq Exotica   Luxury  Mumbai
# 4    53.33   Standard  Atliq Exotica   Luxury  Mumbai

# %%
df.groupby('city')['occ_pct'].mean().round(2)
# Out:
# city
# Bangalore    56.33
# Delhi        61.51
# Hyderabad    58.12
# Mumbai       57.91
# Name: occ_pct, dtype: float64

# %%
df.groupby('city')['occ_pct'].mean().round(2).plot(kind = 'bar', rot = 45, title = 'Occupancy % By City')
# Out:
# <Axes: title={'center': 'Occupancy % By City'}, xlabel='city'>

# %%
#3. When was the occupancy better? Weekday or Weekend?

df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df = pd.merge(df_date, df, left_on = 'date', right_on = 'check_in_date')
df.head()
# Out:
#         date  mmm yy week no  day_type  property_id check_in_date  \
# 0  10-May-22  May 22    W 20  weekeday        16559     10-May-22
# 1  10-May-22  May 22    W 20  weekeday        16559     10-May-22
# 2  10-May-22  May 22    W 20  weekeday        16559     10-May-22
# 3  10-May-22  May 22    W 20  weekeday        16559     10-May-22
# 4  10-May-22  May 22    W 20  weekeday        19562     10-May-22
#
#   room_category  successful_bookings  capacity  occ_pct    room_class  \
# 0           RT1                   18      30.0    60.00      Standard
# 1           RT2                   25      41.0    60.98         Elite
# 2           RT3                   20      32.0    62.50       Premium
# 3           RT4                   13      18.0    72.22  Presidential
# 4           RT1                   18      30.0    60.00      Standard
#
#    property_name category       city
# 0  Atliq Exotica   Luxury     Mumbai
# 1  Atliq Exotica   Luxury     Mumbai
# ...

# %%
df.drop(['date'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    mmm yy week no  day_type  property_id check_in_date room_category  \
# 0  May 22    W 20  weekeday        16559     10-May-22           RT1
# 1  May 22    W 20  weekeday        16559     10-May-22           RT2
# 2  May 22    W 20  weekeday        16559     10-May-22           RT3
# 3  May 22    W 20  weekeday        16559     10-May-22           RT4
# 4  May 22    W 20  weekeday        19562     10-May-22           RT1
#
#    successful_bookings  capacity  occ_pct    room_class  property_name  \
# 0                   18      30.0    60.00      Standard  Atliq Exotica
# 1                   25      41.0    60.98         Elite  Atliq Exotica
# 2                   20      32.0    62.50       Premium  Atliq Exotica
# 3                   13      18.0    72.22  Presidential  Atliq Exotica
# 4                   18      30.0    60.00      Standard      Atliq Bay
#
#   category       city
# 0   Luxury     Mumbai
# 1   Luxury     Mumbai
# 2   Luxury     Mumbai
# 3   Luxury     Mumbai
# ...

# %%
df.groupby('day_type')['occ_pct'].mean().round(2)
# Out:
# day_type
# weekeday    50.88
# weekend     72.34
# Name: occ_pct, dtype: float64

# %%
df.groupby('day_type')['occ_pct'].mean().round(2).plot(kind = 'pie', autopct = '%1.1f%%', title = 'Occupancy % By Day type')
# Out:
# <Axes: title={'center': 'Occupancy % By Day type'}, ylabel='occ_pct'>

# %%
#4: In the month of June, what is the occupancy for different cities

df_june = df[df['mmm yy'] == 'Jun 22']
df_june.groupby(['mmm yy', 'city'])['occ_pct'].mean().round(2)
# Out:
# mmm yy  city
# Jun 22  Bangalore    56.44
#         Delhi        62.47
#         Hyderabad    58.46
#         Mumbai       58.38
# Name: occ_pct, dtype: float64

# %%
df_june.groupby(['mmm yy', 'city'])['occ_pct'].mean().round(2).plot(kind = "bar", rot = 45)
# Out:
# <Axes: xlabel='mmm yy,city'>

# %%
#5: We got new data for the month of august. Append that to existing data

df_new_aug = pd.read_csv('datasets/new_data_august.csv')
df_new_aug.head()
# Out:
#    property_id  property_name  category       city room_category room_class  \
# 0        16559  Atliq Exotica    Luxury     Mumbai           RT1   Standard
# 1        19562      Atliq Bay    Luxury  Bangalore           RT1   Standard
# 2        19563   Atliq Palace  Business  Bangalore           RT1   Standard
# 3        19558   Atliq Grands    Luxury  Bangalore           RT1   Standard
# 4        19560     Atliq City  Business  Bangalore           RT1   Standard
#
#   check_in_date  mmm yy week no  day_type  successful_bookings  capacity  \
# 0     01-Aug-22  Aug-22    W 32  weekeday                   30        30
# 1     01-Aug-22  Aug-22    W 32  weekeday                   21        30
# 2     01-Aug-22  Aug-22    W 32  weekeday                   23        30
# 3     01-Aug-22  Aug-22    W 32  weekeday                   30        40
# 4     01-Aug-22  Aug-22    W 32  weekeday                   20        26
#
#      occ%
# 0  100.00
# 1   70.00
# 2   76.67
# 3   75.00
# 4   76.92

# %%
df.shape
# Out:
# (6497, 13)

# %%
df_new_aug.shape
# Out:
# (7, 13)

# %%
latest_df = pd.concat([df, df_new_aug], ignore_index = True, axis = 0)
latest_df
# Out:
#       mmm yy week no  day_type  property_id check_in_date room_category  \
# 0     May 22    W 20  weekeday        16559     10-May-22           RT1
# 1     May 22    W 20  weekeday        16559     10-May-22           RT2
# 2     May 22    W 20  weekeday        16559     10-May-22           RT3
# 3     May 22    W 20  weekeday        16559     10-May-22           RT4
# 4     May 22    W 20  weekeday        19562     10-May-22           RT1
# ...      ...     ...       ...          ...           ...           ...
# 6499  Aug-22    W 32  weekeday        19563     01-Aug-22           RT1
# 6500  Aug-22    W 32  weekeday        19558     01-Aug-22           RT1
# 6501  Aug-22    W 32  weekeday        19560     01-Aug-22           RT1
# 6502  Aug-22    W 32  weekeday        17561     01-Aug-22           RT1
# 6503  Aug-22    W 32  weekeday        17564     01-Aug-22           RT1
#
#       successful_bookings  capacity  occ_pct    room_class  property_name  \
# ...

# %%
latest_df['occ_pct'] = latest_df['occ_pct'].fillna(latest_df['occ%'])

# %%
latest_df
# Out:
#       mmm yy week no  day_type  property_id check_in_date room_category  \
# 0     May 22    W 20  weekeday        16559     10-May-22           RT1
# 1     May 22    W 20  weekeday        16559     10-May-22           RT2
# 2     May 22    W 20  weekeday        16559     10-May-22           RT3
# 3     May 22    W 20  weekeday        16559     10-May-22           RT4
# 4     May 22    W 20  weekeday        19562     10-May-22           RT1
# ...      ...     ...       ...          ...           ...           ...
# 6499  Aug-22    W 32  weekeday        19563     01-Aug-22           RT1
# 6500  Aug-22    W 32  weekeday        19558     01-Aug-22           RT1
# 6501  Aug-22    W 32  weekeday        19560     01-Aug-22           RT1
# 6502  Aug-22    W 32  weekeday        17561     01-Aug-22           RT1
# 6503  Aug-22    W 32  weekeday        17564     01-Aug-22           RT1
#
#       successful_bookings  capacity  occ_pct    room_class  property_name  \
# ...

# %%
latest_df.drop(['occ%'], axis = 1, inplace = True)

# %%
latest_df
# Out:
#       mmm yy week no  day_type  property_id check_in_date room_category  \
# 0     May 22    W 20  weekeday        16559     10-May-22           RT1
# 1     May 22    W 20  weekeday        16559     10-May-22           RT2
# 2     May 22    W 20  weekeday        16559     10-May-22           RT3
# 3     May 22    W 20  weekeday        16559     10-May-22           RT4
# 4     May 22    W 20  weekeday        19562     10-May-22           RT1
# ...      ...     ...       ...          ...           ...           ...
# 6499  Aug-22    W 32  weekeday        19563     01-Aug-22           RT1
# 6500  Aug-22    W 32  weekeday        19558     01-Aug-22           RT1
# 6501  Aug-22    W 32  weekeday        19560     01-Aug-22           RT1
# 6502  Aug-22    W 32  weekeday        17561     01-Aug-22           RT1
# 6503  Aug-22    W 32  weekeday        17564     01-Aug-22           RT1
#
#       successful_bookings  capacity  occ_pct    room_class  property_name  \
# ...

# %%
#6. Print revenue realized per city

df_bookings.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6  May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 7  May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 7        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized
# ...

# %%
df_revenue = pd.merge(df_bookings, df_hotels, on = 'property_id')
df_revenue
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558     30-04-22      1/5/2022
# 1        May012216558RT15        16558     27-04-22      1/5/2022
# 2        May012216558RT16        16558     1/5/2022      1/5/2022
# 3        May012216558RT17        16558     28-04-22      1/5/2022
# 4        May012216558RT18        16558     26-04-22      1/5/2022
# ...                   ...          ...          ...           ...
# 134568   Jul312217564RT45        17564     30-07-22      31-07-22
# 134569   Jul312217564RT46        17564     29-07-22      31-07-22
# 134570   Jul312217564RT48        17564     30-07-22      31-07-22
# 134571   Jul312217564RT49        17564     29-07-22      31-07-22
# 134572  Jul312217564RT410        17564     31-07-22      31-07-22
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_revenue.groupby('city')['revenue_realized'].sum()
# Out:
# city
# Bangalore    420383550
# Delhi        294404488
# Hyderabad    325179310
# Mumbai       668569251
# Name: revenue_realized, dtype: int64

# %%
df_revenue.groupby('city')['revenue_realized'].sum().plot(kind = 'bar', rot = 45, title = 'Revenue By City')
# Out:
# <Axes: title={'center': 'Revenue By City'}, xlabel='city'>

# %%
#7. Print month by month revenue

df_revenue['check_in_date'] = pd.to_datetime(df_revenue['check_in_date'], format = 'mixed', dayfirst = True, errors = 'coerce')
df_revenue.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558     30-04-22    2022-05-01      2/5/2022
# 1  May012216558RT15        16558     27-04-22    2022-05-01      2/5/2022
# 2  May012216558RT16        16558     1/5/2022    2022-05-01      3/5/2022
# 3  May012216558RT17        16558     28-04-22    2022-05-01      6/5/2022
# 4  May012216558RT18        16558     26-04-22    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_revenue['booking_date'] = pd.to_datetime(df_revenue['booking_date'], format = 'mixed', dayfirst = True, errors = 'coerce')
df_revenue.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558   2022-04-30    2022-05-01      2/5/2022
# 1  May012216558RT15        16558   2022-04-27    2022-05-01      2/5/2022
# 2  May012216558RT16        16558   2022-05-01    2022-05-01      3/5/2022
# 3  May012216558RT17        16558   2022-04-28    2022-05-01      6/5/2022
# 4  May012216558RT18        16558   2022-04-26    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
#    revenue_generated  revenue_realized property_name category   city
# ...

# %%
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
df_date['date'] = pd.to_datetime(df_date['date'], format = 'mixed', dayfirst = True, errors = 'coerce')
df_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0 2022-05-01  May 22    W 19   weekend
# 1 2022-05-02  May 22    W 19  weekeday
# 2 2022-05-03  May 22    W 19  weekeday
# 3 2022-05-04  May 22    W 19  weekeday
# 4 2022-05-05  May 22    W 19  weekeday

# %%
df_revenue = pd.merge(df_revenue, df_date, left_on = 'check_in_date', right_on = 'date')
df_revenue
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT12        16558   2022-04-30    2022-05-01
# 1        May012216558RT15        16558   2022-04-27    2022-05-01
# 2        May012216558RT16        16558   2022-05-01    2022-05-01
# 3        May012216558RT17        16558   2022-04-28    2022-05-01
# 4        May012216558RT18        16558   2022-04-26    2022-05-01
# ...                   ...          ...          ...           ...
# 134568   Jul312217564RT45        17564   2022-07-30    2022-07-31
# 134569   Jul312217564RT46        17564   2022-07-29    2022-07-31
# 134570   Jul312217564RT48        17564   2022-07-30    2022-07-31
# 134571   Jul312217564RT49        17564   2022-07-29    2022-07-31
# 134572  Jul312217564RT410        17564   2022-07-31    2022-07-31
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           2/5/2022        2.0           RT1           others            NaN
# ...

# %%
df_revenue.groupby('mmm yy')['revenue_realized'].sum()
# Out:
# mmm yy
# Jul 22    572843348
# Jun 22    553925855
# May 22    581767396
# Name: revenue_realized, dtype: int64

# %%
df_revenue.groupby('mmm yy')['revenue_realized'].sum().plot(kind = 'line', marker = '.', title = 'Revenue vs Month')
# Out:
# <Axes: title={'center': 'Revenue vs Month'}, xlabel='mmm yy'>

# %%
df_hotels.head()
# Out:
#    property_id  property_name  category    city
# 0        16558   Atliq Grands    Luxury   Delhi
# 1        16559  Atliq Exotica    Luxury  Mumbai
# 2        16560     Atliq City  Business   Delhi
# 3        16561      Atliq Blu    Luxury   Delhi
# 4        16562      Atliq Bay    Luxury   Delhi

# %%
#Exercise-1. Print revenue realized per hotel type

df_revenue = pd.merge(df_revenue, df_hotels, on = 'property_id')
df_revenue.head()
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT12        16558   2022-04-30    2022-05-01      2/5/2022
# 1  May012216558RT15        16558   2022-04-27    2022-05-01      2/5/2022
# 2  May012216558RT16        16558   2022-05-01    2022-05-01      3/5/2022
# 3  May012216558RT17        16558   2022-04-28    2022-05-01      6/5/2022
# 4  May012216558RT18        16558   2022-04-26    2022-05-01      3/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0        2.0           RT1           others            NaN      Cancelled
# 1        4.0           RT1    direct online            5.0    Checked Out
# 2        2.0           RT1           others            4.0    Checked Out
# 3        2.0           RT1           others            NaN      Cancelled
# 4        2.0           RT1          logtrip            NaN        No Show
#
# ...

# %%
df_revenue.groupby('category')['revenue_realized'].sum()
# Out:
# category
# Business     655967037
# Luxury      1052569562
# Name: revenue_realized, dtype: int64

# %%
#Exercise-2 Print average rating per city

df_revenue.groupby('city')['ratings_given'].mean().round(2)
# Out:
# city
# Bangalore    3.41
# Delhi        3.78
# Hyderabad    3.66
# Mumbai       3.65
# Name: ratings_given, dtype: float64

# %%
#Exercise-3 Print a pie chart of revenue realized per booking platform

df_revenue.groupby('booking_platform')['revenue_realized'].sum().plot(kind = 'pie', autopct = '%1.1f%%', title = 'Revenue per Category')
# Out:
# <Axes: title={'center': 'Revenue per Category'}, ylabel='revenue_realized'>

# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydantic
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
